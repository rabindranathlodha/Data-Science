# %%
import pandas as pd

# %%
df = pd.read_csv('filmdata.csv')

# %%
df
# Out:
#           Actor Name                      Film  Year          Genre  \
# 0     Shah Rukh Khan                   Pathaan  2023         Action
# 1        Salman Khan           Tiger Zinda Hai  2017         Action
# 2         Aamir Khan                    Dangal  2016          Drama
# 3     Hrithik Roshan                       War  2019         Action
# 4       Akshay Kumar                    Kesari  2019     Historical
# 5      Ranbir Kapoor                     Sanju  2018         Biopic
# 6   Deepika Padukone                 Padmaavat  2018     Historical
# 7      Ranveer Singh           Bajirao Mastani  2015     Historical
# 8         Alia Bhatt                     Raazi  2018       Thriller
# 9         Ajay Devgn                   Tanhaji  2020     Historical
# 10     Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror-Comedy
# 11     Vicky Kaushal  URI: The Surgical Strike  2019         Action
# 12     Shahid Kapoor               Kabir Singh  2019          Drama
# ...

# %%
df.sort_values('Year')
# Out:
#           Actor Name                      Film  Year          Genre  \
# 7      Ranveer Singh           Bajirao Mastani  2015     Historical
# 2         Aamir Khan                    Dangal  2016          Drama
# 1        Salman Khan           Tiger Zinda Hai  2017         Action
# 5      Ranbir Kapoor                     Sanju  2018         Biopic
# 6   Deepika Padukone                 Padmaavat  2018     Historical
# 8         Alia Bhatt                     Raazi  2018       Thriller
# 14      John Abraham                   Parmanu  2018          Drama
# 3     Hrithik Roshan                       War  2019         Action
# 12     Shahid Kapoor               Kabir Singh  2019          Drama
# 4       Akshay Kumar                    Kesari  2019     Historical
# 11     Vicky Kaushal  URI: The Surgical Strike  2019         Action
# 9         Ajay Devgn                   Tanhaji  2020     Historical
# 13      Varun Dhawan                   Bhediya  2022  Comedy-Horror
# ...

# %%
df.sort_values('Year', ascending=False)
# Out:
#           Actor Name                      Film  Year          Genre  \
# 0     Shah Rukh Khan                   Pathaan  2023         Action
# 13      Varun Dhawan                   Bhediya  2022  Comedy-Horror
# 10     Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror-Comedy
# 9         Ajay Devgn                   Tanhaji  2020     Historical
# 11     Vicky Kaushal  URI: The Surgical Strike  2019         Action
# 4       Akshay Kumar                    Kesari  2019     Historical
# 3     Hrithik Roshan                       War  2019         Action
# 12     Shahid Kapoor               Kabir Singh  2019          Drama
# 8         Alia Bhatt                     Raazi  2018       Thriller
# 6   Deepika Padukone                 Padmaavat  2018     Historical
# 5      Ranbir Kapoor                     Sanju  2018         Biopic
# 14      John Abraham                   Parmanu  2018          Drama
# 1        Salman Khan           Tiger Zinda Hai  2017         Action
# ...

# %%
df2 = df.sort_values(['Year', 'IMDb']).copy()

# %%
df2
# Out:
#           Actor Name                      Film  Year          Genre  \
# 7      Ranveer Singh           Bajirao Mastani  2015     Historical
# 2         Aamir Khan                    Dangal  2016          Drama
# 1        Salman Khan           Tiger Zinda Hai  2017         Action
# 6   Deepika Padukone                 Padmaavat  2018     Historical
# 8         Alia Bhatt                     Raazi  2018       Thriller
# 14      John Abraham                   Parmanu  2018          Drama
# 5      Ranbir Kapoor                     Sanju  2018         Biopic
# 3     Hrithik Roshan                       War  2019         Action
# 12     Shahid Kapoor               Kabir Singh  2019          Drama
# 4       Akshay Kumar                    Kesari  2019     Historical
# 11     Vicky Kaushal  URI: The Surgical Strike  2019         Action
# 9         Ajay Devgn                   Tanhaji  2020     Historical
# 10     Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror-Comedy
# ...

# %%
df2.reset_index()
# Out:
#     index        Actor Name                      Film  Year          Genre  \
# 0       7     Ranveer Singh           Bajirao Mastani  2015     Historical
# 1       2        Aamir Khan                    Dangal  2016          Drama
# 2       1       Salman Khan           Tiger Zinda Hai  2017         Action
# 3       6  Deepika Padukone                 Padmaavat  2018     Historical
# 4       8        Alia Bhatt                     Raazi  2018       Thriller
# 5      14      John Abraham                   Parmanu  2018          Drama
# 6       5     Ranbir Kapoor                     Sanju  2018         Biopic
# 7       3    Hrithik Roshan                       War  2019         Action
# 8      12     Shahid Kapoor               Kabir Singh  2019          Drama
# 9       4      Akshay Kumar                    Kesari  2019     Historical
# 10     11     Vicky Kaushal  URI: The Surgical Strike  2019         Action
# ...
