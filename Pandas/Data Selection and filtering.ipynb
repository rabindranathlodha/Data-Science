# %%
import pandas as pd
df = pd.read_csv("Bollywood_Films.csv")

# %%
df
# Out:
#           Actor Name                      Film  Year          Genre  \
# 0     Shah Rukh Khan                   Pathaan  2023         Action
# 1        Salman Khan           Tiger Zinda Hai  2017         Action
# 2         Aamir Khan                    Dangal  2016          Drama
# 3     Hrithik Roshan                       War  2019         Action
# 4       Akshay Kumar                    Kesari  2019     Historical
# 5      Ranbir Kapoor                     Sanju  2018         Biopic
# 6   Deepika Padukone                 Padmaavat  2018     Historical
# 7      Ranveer Singh           Bajirao Mastani  2015     Historical
# 8         Alia Bhatt                     Raazi  2018       Thriller
# 9         Ajay Devgn                   Tanhaji  2020     Historical
# 10     Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror-Comedy
# 11     Vicky Kaushal  URI: The Surgical Strike  2019         Action
# 12     Shahid Kapoor               Kabir Singh  2019          Drama
# ...

# %%
df['Actor Name']
# Out:
# 0       Shah Rukh Khan
# 1          Salman Khan
# 2           Aamir Khan
# 3       Hrithik Roshan
# 4         Akshay Kumar
# 5        Ranbir Kapoor
# 6     Deepika Padukone
# 7        Ranveer Singh
# 8           Alia Bhatt
# 9           Ajay Devgn
# 10       Kartik Aaryan
# 11       Vicky Kaushal
# 12       Shahid Kapoor
# 13        Varun Dhawan
# 14        John Abraham
# Name: Actor Name, dtype: object

# %%
df[['Actor Name', 'IMDb']]
# Out:
#           Actor Name  IMDb
# 0     Shah Rukh Khan   7.0
# 1        Salman Khan   6.0
# 2         Aamir Khan   8.4
# 3     Hrithik Roshan   6.5
# 4       Akshay Kumar   7.4
# 5      Ranbir Kapoor   7.8
# 6   Deepika Padukone   7.0
# 7      Ranveer Singh   7.2
# 8         Alia Bhatt   7.7
# 9         Ajay Devgn   7.6
# 10     Kartik Aaryan   6.6
# 11     Vicky Kaushal   8.2
# 12     Shahid Kapoor   7.1
# 13      Varun Dhawan   7.3
# 14      John Abraham   7.7

# %%
df
# Out:
#           Actor Name                      Film  Year          Genre  \
# 0     Shah Rukh Khan                   Pathaan  2023         Action
# 1        Salman Khan           Tiger Zinda Hai  2017         Action
# 2         Aamir Khan                    Dangal  2016          Drama
# 3     Hrithik Roshan                       War  2019         Action
# 4       Akshay Kumar                    Kesari  2019     Historical
# 5      Ranbir Kapoor                     Sanju  2018         Biopic
# 6   Deepika Padukone                 Padmaavat  2018     Historical
# 7      Ranveer Singh           Bajirao Mastani  2015     Historical
# 8         Alia Bhatt                     Raazi  2018       Thriller
# 9         Ajay Devgn                   Tanhaji  2020     Historical
# 10     Kartik Aaryan         Bhool Bhulaiyaa 2  2022  Horror-Comedy
# 11     Vicky Kaushal  URI: The Surgical Strike  2019         Action
# 12     Shahid Kapoor               Kabir Singh  2019          Drama
# ...

# %%
df.loc[1]
# Out:
# Actor Name                  Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# Box Office (₹ Crore)                565
# IMDb                                6.0
# Name: 1, dtype: object

# %%
df[df['IMDb'] > 8]
# Out:
#        Actor Name                      Film  Year   Genre  \
# 2      Aamir Khan                    Dangal  2016   Drama
# 11  Vicky Kaushal  URI: The Surgical Strike  2019  Action
#
#     Box Office (₹ Crore)  IMDb
# 2                   2024   8.4
# 11                   342   8.2
